# %%
# !pip list
# Out:
# Package                            Version         Location
# ---------------------------------- --------------- ----------------------------------------------------------------------------------------------
# absl-py                            0.7.1
# AGILe                              1.5.0
# aiobotocore                        1.1.1
# aiofiles                           0.5.0
# aiohttp                            3.6.2
# aioitertools                       0.7.1
# aiostream                          0.4.1
# altair                             4.1.0
# appdirs                            1.4.4
# argon2-cffi                        20.1.0
# asciitree                          0.3.3
# asn1crypto                         0.24.0
# astor                              0.8.0
# astroid                            2.3.3
# astropy                            4.0.1.post1
# astropy-healpix                    0.5
# async-generator                    1.10
# async-timeout                      3.0.1
# ...
